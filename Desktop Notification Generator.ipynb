# %%
import time
# time module allows to work with time in Python. 
#It allows functionality like getting the current time, pausing the Program from executing, etc
from plyer import notification

#Plyer is a Python library for accessing features of your hardware / platforms. 

#The notification class provides a method called notify, which accepts the following parameters
# Python’s if __name__ == "__main__" idiom is just a normal conditional block:
#if __name__ == "__main__" as a way to store code that should only run when your file is ex ecuted as a script.
#When you run the file as a script by passing the file object to your Python interpreter, the expression __name__ == "__main__" returns True.
if __name__ == "__main__":
    while True:
        notification.notify(
            title = "ALERT!!!",
            message = "Take a break! It has been an hour!",
            timeout = 10
        )
        time.sleep(3600)

# %%
import time
from plyer import notification

c=0

while (c<5):
    notification.notify(
    title = "ALERT!!!",
    message = "Take a break! It has been an hour!",
    timeout = 2

    )
c=c+2
time.sleep(2)
# Out:
# Exception in thread Thread-213:
# Traceback (most recent call last):
#   File "C:\Users\91884\anaconda3\lib\threading.py", line 980, in _bootstrap_inner
# Exception in thread Thread-2738:
# Traceback (most recent call last):
#   File "C:\Users\91884\anaconda3\lib\threading.py", line 980, in _bootstrap_inner
#     self.run()
#   File "C:\Users\91884\anaconda3\lib\threading.py", line 917, in run
# Exception in thread Thread-201:
# Traceback (most recent call last):
#   File "C:\Users\91884\anaconda3\lib\threading.py", line 980, in _bootstrap_inner
#     self._target(*self._args, **self._kwargs)
#   File "C:\Users\91884\anaconda3\lib\site-packages\plyer\platforms\win\libs\balloontip.py", line 206, in balloon_tip
#     self.run()
#   File "C:\Users\91884\anaconda3\lib\threading.py", line 917, in run
#     WindowsBalloonTip(**kwargs)
#   File "C:\Users\91884\anaconda3\lib\site-packages\plyer\platforms\win\libs\balloontip.py", line 139, in __init__
# ...
